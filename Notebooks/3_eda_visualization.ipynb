# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"E:\Datasets\cleaned_data.csv")

# %%
df.describe()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 177 entries, 0 to 176
# Data columns (total 19 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       177 non-null    object
#  1   Active Cases 2020             177 non-null    int64
#  2   Active Cases 2021             177 non-null    int64
#  3   Active Cases 2022             177 non-null    int64
#  4   Cumulative Total Cases 2020   177 non-null    int64
#  5   Cumulative Total Cases 2021   177 non-null    int64
#  6   Cumulative Total Cases 2022   177 non-null    int64
#  7   Cumulative Total Deaths 2020  177 non-null    int64
#  8   Cumulative Total Deaths 2021  177 non-null    int64
#  9   Cumulative Total Deaths 2022  177 non-null    int64
#  10  Daily New Cases 2020          177 non-null    int64
#  11  Daily New Cases 2021          177 non-null    int64
#  12  Daily New Cases 2022          177 non-null    int64
# ...

# %%
plt.figure(figsize=(10,6))
sns.scatterplot(x=df['Cumulative Total Cases 2022'], y=df['GDP per Capita 2022'])
# Out:
# <Axes: xlabel='Cumulative Total Cases 2022', ylabel='GDP per Capita 2022'>
